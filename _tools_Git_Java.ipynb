// %%
//| echo: false
//| output: true
String script="""
./quarto-utils/_tools_Git.sh
""";

IJava.getKernelInstance().getMagics().applyCellMagic("shell",List.of(""),script);
"";
// Out:
// **Git Repository Status**
//
// | Category | Details |
// |----------|---------|
// | 🌿 Current Branch | `develop` |
// | 📝 Latest Commit | `b3ad722` (2025-02-11 10:09:50) |
// | 🔗 Remote | [git@github.com:ebpro/notebook-containers-intro.git](https://github.com/ebpro/notebook-containers-intro) |
// | 🏷️ Latest Tag | `No tags` |
